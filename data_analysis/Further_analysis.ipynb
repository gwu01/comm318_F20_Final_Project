# %% [markdown]
# # Sourcing Charts
#
# * There will be a lot of overlap from the code I run here in comparison to the code from the other assignment notebooks! The main purpose of the analyses here is to derive the charts that I will be using in my final data story presentation. No new trends, just wanted to consolidate all of the graphics in one place since my kernel was crashing with my other notebooks!

# %%
import pandas as pd
import os

# %%
philly2017_df=pd.read_csv('../data/philly2017.csv')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
cols_to_use = ['objectid', 'dc_dist', 'dispatch_date_time', 'dispatch_date', 'dispatch_time', 'hour_', 'dc_key', 'location_block', 'ucr_general', 'text_general_code', 'point_x', 'point_y', 'lat','lng']
philly2017_df2 = philly2017_df[cols_to_use]
philly2017_df2 = philly2017_df2.rename(columns={
    'objectid':'id',
    'dc_dist':'distance',
    'dispatch_date_time':'datetime',
    'dispatch_date':'date',
    'dispatch_time':'time',
    'hour_':'hour',
    'dc_key':'key',
    'location_block':'location',
    'ucr_general':'ucr',
    'text_general_code':'crimetype',
    'point_x':'x',
    'point_y':'y',
    'lat':'latitutde',
    'lng':'longitude'})
print(philly2017_df2)
# Out:
#              id  distance             datetime        date      time  hour  \
# 0           114         9  2017-07-10 09:35:00  2017-07-10  09:35:00     9
# 1           115         9  2017-10-31 09:59:00  2017-10-31  09:59:00    10
# 2           126         9  2017-11-06 21:22:00  2017-11-06  21:22:00    21
# 3            80         6  2017-08-06 05:51:00  2017-08-06  05:51:00     5
# 4           101        12  2017-10-18 00:10:00  2017-10-18  00:10:00     0
# ...         ...       ...                  ...         ...       ...   ...
# 157309  2610541         7  2017-07-30 15:15:00  2017-07-30  15:15:00    15
# 157310  2610543         3  2017-05-31 12:43:00  2017-05-31  12:43:00    12
# 157311  2610551         2  2017-01-24 08:40:00  2017-01-24  08:40:00     8
# 157312  2554802        22  2017-10-11 00:00:00  2017-10-11  00:00:00    18
# 157313   283701        35  2017-10-11 08:51:00  2017-10-11  08:51:00    14
#
#                  key                      location  ucr  \
# ...

# %%
philly2017_df2['crimetype'].value_counts()
# Out:
# All Other Offenses                         29331
# Other Assaults                             23191
# Thefts                                     22471
# Vandalism/Criminal Mischief                14911
# Theft from Vehicle                         13195
# Fraud                                      11721
# Narcotic / Drug Law Violations              9644
# Aggravated Assault No Firearm               5329
# Burglary Residential                        5173
# Robbery No Firearm                          3497
# DRIVING UNDER THE INFLUENCE                 3456
# Robbery Firearm                             2410
# Aggravated Assault Firearm                  2181
# Weapon Violations                           2111
# Motor Vehicle Theft                         1477
# Burglary Non-Residential                    1388
# Rape                                        1131
# Prostitution and Commercialized Vice        1043
# Other Sex Offenses (Not Commercialized)      947
# ...

# %%
philly2017_df2.groupby('crimetype').size().plot(kind='bar', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='crimetype'>

# %%
philly2018_df=pd.read_csv('../data/philly2018.csv')

# %%
cols_to_use = ['objectid', 'dc_dist', 'dispatch_date_time', 'dispatch_date', 'dispatch_time', 'hour_', 'dc_key', 'location_block', 'ucr_general', 'text_general_code', 'point_x', 'point_y', 'lat','lng']
philly2018_df2 = philly2018_df[cols_to_use]
philly2018_df2 = philly2018_df2.rename(columns={
    'objectid':'id',
    'dc_dist':'distance',
    'dispatch_date_time':'datetime',
    'dispatch_date':'date',
    'dispatch_time':'time',
    'hour_':'hour',
    'dc_key':'key',
    'location_block':'location',
    'ucr_general':'ucr',
    'text_general_code':'crimetype',
    'point_x':'x',
    'point_y':'y',
    'lat':'latitutde',
    'lng':'longitude'})
print(philly2018_df2)
# Out:
#              id  distance             datetime        date      time  hour  \
# 0           116         9  2018-03-29 08:01:00  2018-03-29  08:01:00     8
# 1           117         9  2018-05-18 14:03:00  2018-05-18  14:03:00    14
# 2           118         9  2018-05-24 16:20:00  2018-05-24  16:20:00    16
# 3           119         9  2018-08-07 08:26:00  2018-08-07  08:26:00     8
# 4           127         9  2018-04-03 14:45:00  2018-04-03  14:45:00    14
# ...         ...       ...                  ...         ...       ...   ...
# 152695  2609317        35  2018-01-16 11:52:00  2018-01-16  11:52:00    11
# 152696  2609738         7  2018-03-17 00:20:00  2018-03-17  00:20:00     0
# 152697  2610137         8  2018-08-02 16:48:00  2018-08-02  16:48:00    16
# 152698  2610140        12  2018-06-28 00:38:00  2018-06-28  00:38:00     0
# 152699  2610143        24  2018-07-27 15:48:00  2018-07-27  15:48:00    15
#
#                  key                     location  ucr  \
# ...

# %%
philly2018_df2['crimetype'].value_counts()
# Out:
# All Other Offenses                         25456
# Other Assaults                             23500
# Thefts                                     22903
# Vandalism/Criminal Mischief                14567
# Theft from Vehicle                         13414
# Fraud                                      12286
# Narcotic / Drug Law Violations              9358
# Aggravated Assault No Firearm               5308
# Burglary Residential                        5065
# Robbery No Firearm                          3031
# DRIVING UNDER THE INFLUENCE                 2929
# Aggravated Assault Firearm                  2297
# Weapon Violations                           2195
# Robbery Firearm                             2142
# Motor Vehicle Theft                         1776
# Burglary Non-Residential                    1401
# Rape                                        1056
# Other Sex Offenses (Not Commercialized)      900
# Prostitution and Commercialized Vice         701
# ...

# %%
philly2018_df2.groupby('crimetype').size().plot(kind='bar', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='crimetype'>

# %%
philly2019_df=pd.read_csv('../data/philly2019.csv')

# %%
cols_to_use = ['objectid', 'dc_dist', 'dispatch_date_time', 'dispatch_date', 'dispatch_time', 'hour_', 'dc_key', 'location_block', 'ucr_general', 'text_general_code', 'point_x', 'point_y', 'lat','lng']
philly2019_df2 = philly2019_df[cols_to_use]
philly2019_df2 = philly2019_df2.rename(columns={
    'objectid':'id',
    'dc_dist':'distance',
    'dispatch_date_time':'datetime',
    'dispatch_date':'date',
    'dispatch_time':'time',
    'hour_':'hour',
    'dc_key':'key',
    'location_block':'location',
    'ucr_general':'ucr',
    'text_general_code':'crimetype',
    'point_x':'x',
    'point_y':'y',
    'lat':'latitutde',
    'lng':'longitude'})
print(philly2019_df2)
# Out:
#              id  distance             datetime        date      time  hour  \
# 0           120         9  2019-11-12 09:59:00  2019-11-12  09:59:00   9.0
# 1           128         9  2019-01-19 17:20:00  2019-01-19  17:20:00  17.0
# 2            53        77  2019-12-14 08:07:00  2019-12-14  08:07:00   8.0
# 3            54        77  2019-12-24 14:03:00  2019-12-24  14:03:00  14.0
# 4            55        77  2019-12-25 16:29:00  2019-12-25  16:29:00  16.0
# ...         ...       ...                  ...         ...       ...   ...
# 161082  2610148         6  2019-06-23 20:25:00  2019-06-23  20:25:00  20.0
# 161083  2610544        25  2019-06-23 18:25:00  2019-06-23  18:25:00  18.0
# 161084  2610561        15  2019-08-21 07:05:00  2019-08-21  07:05:00   7.0
# 161085   183424        14  2019-10-23 14:57:00  2019-10-23  14:57:00  19.0
# 161086  2555919        19  2019-01-07 00:00:00  2019-01-07  00:00:00   1.0
#
#                  key                               location  ucr  \
# ...

# %%
philly2019_df2['crimetype'].value_counts()
# Out:
# All Other Offenses                         30739
# Thefts                                     25013
# Other Assaults                             24538
# Vandalism/Criminal Mischief                14676
# Theft from Vehicle                         13157
# Narcotic / Drug Law Violations             10359
# Fraud                                       9755
# Aggravated Assault No Firearm               5601
# Burglary Residential                        4770
# Robbery No Firearm                          3486
# Aggravated Assault Firearm                  2621
# Weapon Violations                           2560
# DRIVING UNDER THE INFLUENCE                 2346
# Robbery Firearm                             2185
# Motor Vehicle Theft                         1910
# Burglary Non-Residential                    1355
# Other Sex Offenses (Not Commercialized)     1006
# Rape                                         989
# Disorderly Conduct                           937
# ...

# %%
philly2019_df2.groupby('crimetype').size().plot(kind='bar', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='crimetype'>

# %%
philly2020_df=pd.read_csv('../data/philly2020.csv')

# %%
cols_to_use = ['objectid', 'dc_dist', 'dispatch_date_time', 'dispatch_date', 'dispatch_time', 'hour_', 'dc_key', 'location_block', 'ucr_general', 'text_general_code', 'point_x', 'point_y', 'lat','lng']
philly2020_df2 = philly2020_df[cols_to_use]
philly2020_df2 = philly2020_df2.rename(columns={
    'objectid':'id',
    'dc_dist':'distance',
    'dispatch_date_time':'datetime',
    'dispatch_date':'date',
    'dispatch_time':'time',
    'hour_':'hour',
    'dc_key':'key',
    'location_block':'location',
    'ucr_general':'ucr',
    'text_general_code':'crimetype',
    'point_x':'x',
    'point_y':'y',
    'lat':'latitutde',
    'lng':'longitude'})
print(philly2020_df2)
# Out:
#              id  distance             datetime        date      time  hour  \
# 0           129         9  2020-03-25 18:32:00  2020-03-25  18:32:00    18
# 1            41        77  2020-03-08 19:08:00  2020-03-08  19:08:00    19
# 2            42        77  2020-03-15 18:41:00  2020-03-15  18:41:00    18
# 3            43        77  2020-03-18 08:17:00  2020-03-18  08:17:00     8
# 4            44        77  2020-04-03 15:32:33  2020-04-03  15:32:33    15
# ...         ...       ...                  ...         ...       ...   ...
# 121222  6191501        19  2020-11-06 11:34:35  2020-11-06  11:34:35    11
# 121223  6069435         9  2020-10-31 12:34:19  2020-10-31  12:34:19    12
# 121224  6191891         2  2020-11-06 16:51:45  2020-11-06  16:51:45    16
# 121225  6067412        15  2020-10-31 18:24:21  2020-10-31  18:24:21    18
# 121226  6067417        16  2020-10-31 18:07:47  2020-10-31  18:07:47    18
#
# ...

# %%
philly2020_df2['crimetype'].value_counts()
# Out:
# Other Assaults                             19323
# Thefts                                     18000
# All Other Offenses                         14713
# Vandalism/Criminal Mischief                12781
# Theft from Vehicle                         11138
# Fraud                                       7592
# Narcotic / Drug Law Violations              5833
# Aggravated Assault No Firearm               4727
# Motor Vehicle Theft                         4362
# Aggravated Assault Firearm                  3312
# Burglary Residential                        3076
# Burglary Non-Residential                    3015
# Weapon Violations                           2964
# Robbery No Firearm                          2438
# Robbery Firearm                             1479
# DRIVING UNDER THE INFLUENCE                 1461
# Recovered Stolen Motor Vehicle              1150
# Disorderly Conduct                           702
# Rape                                         692
# ...

# %%
philly2020_df2.groupby('crimetype').size().plot(kind='bar', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='crimetype'>
